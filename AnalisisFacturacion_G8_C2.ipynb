# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos 164300.00         6900.00
# 1    Mesa de comedor                Muebles 192300.00         8400.00
# 2      Juego de mesa               Juguetes 209600.00        15900.00
# 3         Microondas      Electrodomésticos 757500.00        41000.00
# 4   Silla de oficina                Muebles 335200.00        20200.00
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas   lat    lon
# 0  Tarjeta de crédito                   8  4.61 -74.08
# 1  Tarjeta de crédito                   4  6.25 -75.56
# 2  Tarjeta de crédito                   1 10.40 -75.51
# 3               Nequi                   1  3.44 -76.52
# 4               Nequi                   1  6.25 -75.56

# %% [markdown]
# #0. Análisis Exploratorio y fusion de dataframes

# %% [markdown]
# Voy a unir todo en un mismo dataframe y le voy a agregar una columna con el número de tienda

# %%
#Agrego columna tienda
tienda['tienda'] = 1
tienda2['tienda'] = 2
tienda3['tienda'] = 3
tienda4['tienda'] = 4

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos 164300.00         6900.00
# 1    Mesa de comedor                Muebles 192300.00         8400.00
# 2      Juego de mesa               Juguetes 209600.00        15900.00
# 3         Microondas      Electrodomésticos 757500.00        41000.00
# 4   Silla de oficina                Muebles 335200.00        20200.00
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas   lat    lon  tienda
# 0  Tarjeta de crédito                   8  4.61 -74.08       1
# 1  Tarjeta de crédito                   4  6.25 -75.56       1
# 2  Tarjeta de crédito                   1 10.40 -75.51       1
# 3               Nequi                   1  3.44 -76.52       1
# 4               Nequi                   1  6.25 -75.56       1

# %%
#contateno las 4 tiendas en 1 solo dataframe
df=pd.concat([tienda,tienda2,tienda3,tienda4])

# %%
df.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos 164300.00         6900.00
# 1    Mesa de comedor                Muebles 192300.00         8400.00
# 2      Juego de mesa               Juguetes 209600.00        15900.00
# 3         Microondas      Electrodomésticos 757500.00        41000.00
# 4   Silla de oficina                Muebles 335200.00        20200.00
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas   lat    lon  tienda
# 0  Tarjeta de crédito                   8  4.61 -74.08       1
# 1  Tarjeta de crédito                   4  6.25 -75.56       1
# 2  Tarjeta de crédito                   1 10.40 -75.51       1
# 3               Nequi                   1  3.44 -76.52       1
# 4               Nequi                   1  6.25 -75.56       1

# %%
df.tail()
# Out:
#                 Producto   Categoría del Producto    Precio  Costo de envío  \
# 2353     Mesa de comedor                  Muebles 227700.00        12600.00
# 2354    Silla de oficina                  Muebles 342000.00        18600.00
# 2355        Vaso térmico     Deportes y diversión  36700.00         2400.00
# 2356        Set de ollas  Artículos para el hogar 151800.00         8300.00
# 2357  Cuerda para saltar     Deportes y diversión  11200.00         1300.00
#
#      Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 2353      12/02/2020   Camila Rivera        Medellín             5
# 2354      17/05/2022   Felipe Santos     Bucaramanga             5
# 2355      03/05/2022   Camila Rivera          Bogotá             5
# 2356      15/06/2020  Blanca Ramirez            Cali             5
# 2357      17/11/2021   Felipe Santos          Bogotá             5
#
#           Método de pago  Cantidad de cuotas  lat    lon  tienda
# 2353  Tarjeta de crédito                   1 6.25 -75.56       4
# 2354  Tarjeta de crédito                   3 7.13 -73.12       4
# 2355  Tarjeta de crédito                   1 4.61 -74.08       4
# 2356  Tarjeta de crédito                   1 3.44 -76.52       4
# 2357  Tarjeta de crédito                   1 4.61 -74.08       4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9435 entries, 0 to 2357
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                9435 non-null   object
#  1   Categoría del Producto  9435 non-null   object
#  2   Precio                  9435 non-null   float64
#  3   Costo de envío          9435 non-null   float64
#  4   Fecha de Compra         9435 non-null   object
#  5   Vendedor                9435 non-null   object
#  6   Lugar de Compra         9435 non-null   object
#  7   Calificación            9435 non-null   int64
#  8   Método de pago          9435 non-null   object
#  9   Cantidad de cuotas      9435 non-null   int64
#  10  lat                     9435 non-null   float64
#  11  lon                     9435 non-null   float64
#  12  tienda                  9435 non-null   int64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 1.3+ MB

# %% [markdown]
# Total 9435 ventas entre las 4 tiendas, no hay campos nulos

# %%
#Formateo para que los floats se vean sin decimales
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna **Precio** de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
# Voy a hacer una función que reciba el dataframe y retorne otro DataFrame con la tienda y la facturación total
# Voy a usar Type Hint y Docstrings


def totalFacturacion(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Función que recibe un DataFrame y devuelve otro DataFrame
    con el número de tienda y la sumatoria de lo facturado en cada tienda.

    Columnas de salida:
    - tienda (int)
    - facturacion_total (float)
    '''

    facturacion = df.groupby('tienda', as_index=False)['Precio'].sum()
    facturacion.rename(columns={'Precio': 'facturacion_total'}, inplace=True)
    return facturacion


facturacion_por_tienda = totalFacturacion(df)
facturacion_por_tienda['facturacion_total'] = facturacion_por_tienda['facturacion_total']
print(facturacion_por_tienda)
# Out:
#    tienda  facturacion_total
# 0       1      1150880400.00
# 1       2      1116343500.00
# 2       3      1098019600.00
# 3       4      1038375700.00

# %% [markdown]
# ##1.1 Visualizaciones para Análisis de Facturación
#
#
# *   Bar Plot
# *   Pie Chart
# *   Line Plot

# %%
import matplotlib.pyplot as plt

# %%
#Bar Plot

# Hacer el Bar Plot directamente al iterar sobre el nuevo DataFrame
plt.figure(figsize=(8,5))
bars = plt.bar(facturacion_por_tienda['tienda'], facturacion_por_tienda['facturacion_total'], color='skyblue')

# Agregar etiquetas arriba de las barras
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 5000000, f'{yval:,.0f}', ha='center', va='bottom', fontsize=8)

plt.xlabel('Tienda')
plt.ylabel('Facturación Total en billones')
plt.title('Facturación Total por Tienda')
plt.xticks(facturacion_por_tienda['tienda'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#Pie Chart

plt.figure(figsize=(7,4))
plt.pie(facturacion_por_tienda['facturacion_total'],
        labels=None,
        autopct='%1.1f%%',
        startangle=140,
        colors=plt.cm.Paired.colors)


# DEFINIMOS las etiquetas antes
labels = [f'Tienda: {tienda}' for tienda in facturacion_por_tienda['tienda']]

# Agregamos la leyenda abajo
plt.legend(
    labels,
    loc='lower center',
    bbox_to_anchor=(0.5, -0.3),
    ncol=2,  # Número de columnas en la leyenda
    frameon=False
)

plt.title('Distribución de Facturación por Tienda')
plt.axis('equal')  # Mantiene el círculo bien redondo
plt.tight_layout()
plt.show()

# %%
#Line Plot

plt.figure(figsize=(8,5))
plt.plot(facturacion_por_tienda['tienda'], facturacion_por_tienda['facturacion_total'], marker='o', linestyle='-', color='green')

# Agregar valores en cada punto
for i, val in enumerate(facturacion_por_tienda['facturacion_total']):
    plt.text(facturacion_por_tienda['tienda'][i], val + 5000000, f'{val:,.0f}', ha='center', va='bottom', fontsize=8)

plt.xlabel('Tienda')
plt.ylabel('Facturación Total en Billones')
plt.title('Facturación Total por Tienda (Line Plot)')
plt.xticks(facturacion_por_tienda['tienda'])
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la **cantidad de productos vendidos por categoría** en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, **mostrando las categorías más populares de cada tienda**.

# %%
# Voy a hacer una función que reciba el dataframe y retorne otro DataFrame con la tienda y la venta por categoría
# Voy a usar Type Hint y Docstrings
import pandas as pd

def catPorTienda(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Función que recibe un DataFrame y devuelve otro DataFrame
    con el número de tienda, la categoría y cantidad de productos de esa categoría vendida.

    Columnas de salida:
    - tienda (int)
    - categoría (str)
    - cantidad (int)
    '''
    categoriasVend = df.groupby(['tienda', 'Categoría del Producto']).size().reset_index(name='cantidad')

    return categoriasVend

# Ejemplo de uso
# Asumiendo que tienes el DataFrame 'df' ya cargado
categoriasVend = catPorTienda(df)
print(categoriasVend)
# Out:
#     tienda   Categoría del Producto  cantidad
# 0        1  Artículos para el hogar       171
# 1        1     Deportes y diversión       284
# 2        1        Electrodomésticos       312
# 3        1             Electrónicos       448
# 4        1   Instrumentos musicales       182
# 5        1                 Juguetes       324
# 6        1                   Libros       173
# 7        1                  Muebles       465
# 8        2  Artículos para el hogar       181
# 9        2     Deportes y diversión       275
# 10       2        Electrodomésticos       305
# 11       2             Electrónicos       422
# 12       2   Instrumentos musicales       224
# 13       2                 Juguetes       313
# 14       2                   Libros       197
# 15       2                  Muebles       442
# 16       3  Artículos para el hogar       177
# 17       3     Deportes y diversión       277
# 18       3        Electrodomésticos       278
# 19       3             Electrónicos       451
# 20       3   Instrumentos musicales       177
# 21       3                 Juguetes       315
# 22       3                   Libros       185
# 23       3                  Muebles       499
# 24       4  Artículos para el hogar       201
# 25       4     Deportes y diversión       277
# 26       4        Electrodomésticos       254
# 27       4             Electrónicos       451
# 28       4   Instrumentos musicales       170
# 29       4                 Juguetes       338
# 30       4                   Libros       187
# 31       4                  Muebles       480

# %% [markdown]
# ## 2.2 Visualizaciones para análisis por categoría y tienda
#
#
# *   Pie Chart por cada tienda con % de contribución de cada categoría

# %%
import matplotlib.pyplot as plt

# Graficar pie chart para cada tienda
for tienda in categoriasVend['tienda'].unique():
    # Filtrar los datos para la tienda actual
    tienda_data = categoriasVend[categoriasVend['tienda'] == tienda]

    # Crear el gráfico de pie
    plt.figure(figsize=(7,4))
    plt.pie(tienda_data['cantidad'],
            labels=tienda_data['Categoría del Producto'],
            autopct='%1.1f%%',
            startangle=140,
            colors=plt.cm.Paired.colors)

    plt.title(f'Distribución de Productos Vendidos en Tienda {tienda} \n')
    plt.axis('equal')  # Hace el círculo bien redondo
    plt.show()
    print("\n")

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las **calificaciones promedio** de los clientes para cada tienda. El objetivo es conocer la **satisfacción del cliente con los productos vendidos.**

# %%
#Investigo el rango min-max de calificaciones del usuario
print(f"La mínima calificación es {df['Calificación'].min()}")
print(f"La máxima calificación es {df['Calificación'].max()}")
# Out:
# La mínima calificación es 1
# La máxima calificación es 5

# %%
# Voy a hacer una función que reciba el dataframe y retorne otro DataFrame con la tienda y el promedio de satisfacción del cliente
# Voy a usar Type Hint y Docstrings
def calPromedio(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Función que recibe un DataFrame y devuelve otro DataFrame
    con el número de tienda y el promedio de califacación del usuario.

    Columnas de salida:
    - tienda (int)
    - Calificación Promedio (int64) [1--5]
    '''

    promedio = df.groupby('tienda', as_index=False)['Calificación'].mean()
    promedio.rename(columns={'Calificación': 'calificacion_promedio'}, inplace=True)
    promedio = promedio.sort_values(by='calificacion_promedio', ascending=False)

    return promedio

promedio = calPromedio(df)
print(promedio)
# Out:
#    tienda  calificacion_promedio
# 2       3                   4.05
# 1       2                   4.04
# 3       4                   4.00
# 0       1                   3.98

# %% [markdown]
# ## 3.3 Visualización por Satisfacción del cliente

# %%
import matplotlib.pyplot as plt
# Crear el bar chart
plt.figure(figsize=(10,6))
bars = plt.bar(promedio['tienda'], promedio['calificacion_promedio'], color='skyblue')

# Agregar etiquetas de valor arriba de cada barra
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.03, f'{yval:.3f}', ha='center', va='bottom', fontsize=8)

# Etiquetas y título
plt.xlabel('Tienda')
plt.ylabel('Calificación Promedio')
plt.title('Calificación Promedio por Tienda (ordenado de mayor a menor)')
plt.xticks(promedio['tienda'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# identificar qué **productos** fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
# Voy a hacer una función que reciba el dataframe y retorne otro DataFrame con la tienda, el producto y la cantidad vendida de cada uno
# El df se ordenará por tienda y por cantidad de productos vendidos
# Voy a usar Type Hint y Docstrings

dfAux = df.copy()
dfAux['CantidadVendidaProducto'] = 1

def prodVendidos(dfAux: pd.DataFrame) -> pd.DataFrame:
    '''
    Función que recibe un DataFrame y devuelve otro DataFrame
    con el número de tienda, producto y la cantidad vendida de cada uno.

    Columnas de salida:
    - tienda (int)
    - Producto (str)
    - Cantidad (int)
    '''

    # Sumar las cantidades vendidas por tienda y producto
    cantProdVendidos = dfAux.groupby(['tienda', 'Producto'], as_index=False)['CantidadVendidaProducto'].sum()
    contProdVendidos = cantProdVendidos.sort_values(by=['tienda', 'CantidadVendidaProducto'], ascending=[True, False])

    return contProdVendidos


prodVendidos_df = prodVendidos(dfAux)

for tienda in prodVendidos_df['tienda'].unique():
    tienda_data = prodVendidos_df[prodVendidos_df['tienda'] == tienda]
    print(f"Tienda {tienda}:")
    print(f'top 5 artículos vendidos en {tienda}: {tienda_data.head(5)}')
    print("\n")
    print(f'menores 5 artículos vendidos en {tienda}: {tienda_data.tail(5)}')
    print("\n")
# Out:
# Tienda 1:
# top 5 artículos vendidos en 1:     tienda                 Producto  CantidadVendidaProducto
# 1        1                  Armario                       60
# 33       1               Microondas                       60
# 48       1            TV LED UHD 4K                       60
# 40       1         Secadora de ropa                       58
# 9        1  Bloques de construcción                       56
#
#
# menores 5 artículos vendidos en 1:     tienda                   Producto  CantidadVendidaProducto
# 34       1                    Mochila                       39
# 38       1                  Pandereta                       36
# 37       1            Olla de presión                       35
# 4        1  Auriculares con micrófono                       33
# 13       1               Celular ABXY                       33
#
#
# Tienda 2:
# top 5 artículos vendidos en 2:     tienda                   Producto  CantidadVendidaProducto
# 75       2  Iniciando en programación                       65
# 84       2                 Microondas                       62
# 58       2                    Batería                       61
# 72       2          Guitarra acústica                       58
# 89       2                  Pandereta                       58
#
#
# menores 5 artículos vendidos en 2:     tienda         Producto  CantidadVendidaProducto
# 54       2      Auriculares                       37
# 95       2           Sillón                       35
# 74       2        Impresora                       34
# 82       2  Mesa de comedor                       34
# 77       2    Juego de mesa                       32
#
#
# Tienda 3:
# top 5 artículos vendidos en 3:      tienda         Producto  CantidadVendidaProducto
# 129       3    Kit de bancas                       57
# 113       3        Cama king                       56
# 133       3  Mesa de comedor                       56
# 134       3    Mesa de noche                       55
# 143       3     Set de ollas                       55
#
#
# menores 5 artículos vendidos en 3:      tienda                 Producto  CantidadVendidaProducto
# 152       3             Vaso térmico                       38
# 135       3               Microondas                       36
# 136       3                  Mochila                       36
# 144       3             Set de vasos                       36
# 111       3  Bloques de construcción                       35
#
#
# Tienda 4:
# top 5 artículos vendidos en 4:      tienda                   Producto  CantidadVendidaProducto
# 163       4                   Cama box                       62
# 168       4                 Cubertería                       59
# 164       4                  Cama king                       56
# 171       4    Dashboards con Power BI                       56
# 165       4  Carrito de control remoto                       55
#
#
# menores 5 artículos vendidos en 4:      tienda            Producto  CantidadVendidaProducto
# 181       4    Lavadora de ropa                       38
# 192       4        Refrigerador                       38
# 174       4   Guitarra acústica                       37
# 154       4             Armario                       34
# 175       4  Guitarra eléctrica                       33

# %% [markdown]
# ##4.2 Visualizacion de productos mas y menos vendidos por cada tienda

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Función de los productos vendidos
def prodVendidos(dfAux: pd.DataFrame) -> pd.DataFrame:
    '''
    Función que recibe un DataFrame y devuelve otro DataFrame
    con el número de tienda, producto y la cantidad vendida de cada uno.

    Columnas de salida:
    - tienda (int)
    - Producto (str)
    - Cantidad (int)
    '''
    # Sumar las cantidades vendidas por tienda y producto
    cantProdVendidos = dfAux.groupby(['tienda', 'Producto'], as_index=False)['CantidadVendidaProducto'].sum()
    contProdVendidos = cantProdVendidos.sort_values(by=['tienda', 'CantidadVendidaProducto'], ascending=[True, False])

    return contProdVendidos

# Crear una copia del DataFrame original
dfAux = df.copy()
dfAux['CantidadVendidaProducto'] = 1

# Llamar la función
prodVendidos_df = prodVendidos(dfAux)

# Configuración para crear el gráfico
fig, axes = plt.subplots(nrows=len(prodVendidos_df['tienda'].unique()), ncols=1, figsize=(10, 6), sharex=True)

for i, tienda in enumerate(prodVendidos_df['tienda'].unique()):
    tienda_data = prodVendidos_df[prodVendidos_df['tienda'] == tienda]

    # Selección de los 5 productos más vendidos
    top_5 = tienda_data.head(5)
    bottom_5 = tienda_data.tail(5)

    # Visualización de los productos más vendidos
    axes[i].bar(top_5['Producto'], top_5['CantidadVendidaProducto'], color='green', label='Top 5 productos vendidos')
    axes[i].bar(bottom_5['Producto'], bottom_5['CantidadVendidaProducto'], color='red', label='Menos vendidos')

    # Etiquetas y título
    axes[i].set_title(f'Tienda {tienda} - Productos Más y Menos Vendidos')
    axes[i].set_ylabel('Cantidad Vendida')
    axes[i].legend()

# Ajuste de las etiquetas y presentación
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# Calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.

# %%
# Voy a hacer una función que reciba el dataframe y retorne otro DataFrame con la tienda y el promedio del costo de envío
# Voy a usar Type Hint y Docstrings

def calPromCosto(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Función que recibe un DataFrame y devuelve otro DataFrame
    con el número de tienda y el promedio del costo de envío.

    Columnas de salida:
    - tienda (int)
    - Costo Medio de Envío (float 2 decimales)
    '''

    costoEnvioMedio = df.groupby('tienda', as_index=False)['Costo de envío'].mean()
    costoEnvioMedio.rename(columns={'Costo de envío': 'Costo Medio de Envío'}, inplace=True)
    costoEnvioMedio = costoEnvioMedio.sort_values(by='Costo Medio de Envío', ascending=False)

    return costoEnvioMedio

# Usar la función
costoEnvioMedio = calPromCosto(df)
print(costoEnvioMedio)
# Out:
#    tienda  Costo Medio de Envío
# 0       1              26018.61
# 1       2              25216.24
# 2       3              24805.68
# 3       4              23459.46

# %% [markdown]
# ##5.2 Bar Plot con costo de envío

# %%
# Hacer el gráfico
plt.figure(figsize=(8, 6))
bars = plt.bar(costoEnvioMedio['tienda'].astype(str), costoEnvioMedio['Costo Medio de Envío'], color='skyblue')

plt.title('Costo Medio de Envío por Tienda', fontsize=16)
plt.xlabel('Tienda', fontsize=14)
plt.ylabel('Costo Medio de Envío ($)', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Agregar etiquetas de dinero en el eje Y
plt.gca().set_ylim(0, costoEnvioMedio['Costo Medio de Envío'].max() * 1.1)  # Ajusta el límite del eje Y



plt.tight_layout()
plt.show()

# %% [markdown]
# # Concluciones del análisis
# Hay que cerrar la tienda 4
